# %% [markdown]
# ## Variables

# %% [markdown]
# ## simple variables
#
#  - string
#  - int
#  - float
#  - boolean
#
#  ## complex variables
#
#  - list
#  - set
#  - object
#  - tuple

# %%
# string

string = "kølle"


s = str(760183)
print(type(s))
# Out:
# <class 'str'>

# %%
# int

x = 89
y = int("5")

print(f'take {x} and add {y}, you then get {x+y}. Good job')
# Out:
# take 89 and add 5, you then get 94. Good job

# %%
# float

# We can overwrite variable names 
x = 1.1
y= float(42)

print(f"x = {x}, y = {y}, and y is a {type(y)}")
# we can notice that when working with int and float variables they always resolve to float
# Out:
# x = 1.1, y = 42.0, and y is a <class 'float'>

# %%
# Boolean = true/false

is_true = True
is_false = bool(0)
print(is_true)
print(is_false)
# Out:
# True
# False

# %%
for x in range(-1,1):
    if bool(x) == False:
        print(x)
# Out:
# 0

# %%
num_str = "1,1,2,1,3,3"

num =list(num_str.split(","))
print(num)
# Out:
# ['1', '1', '2', '1', '3', '3']
