# %%
import pandas as pd
from scipy import stats
url = "data/penguins_cleaned.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
# 1  Adelie  Torgersen            39.5           17.4                186
# 2  Adelie  Torgersen            40.3           18.0                195
# 3  Adelie  Torgersen            36.7           19.3                193
# 4  Adelie  Torgersen            39.3           20.6                190
#
#    body_mass_g     sex
# 0         3750    male
# 1         3800  female
# 2         3250  female
# 3         3450  female
# 4         3650    male

# %%
for col1 in df.columns:
    for col2 in df.columns:
        if col1 == col2:
            continue
        if pd.api.types.is_numeric_dtype(df[col1]) and pd.api.types.is_numeric_dtype(df[col2]):
            r, p = stats.pearsonr(df[col1], df[col2])
            print(f"{col1}-{col2}: {r:.3f} (p: {p:.3f})")
# Out:
# bill_length_mm-bill_depth_mm: -0.229 (p: 0.000)
# bill_length_mm-flipper_length_mm: 0.653 (p: 0.000)
# bill_length_mm-body_mass_g: 0.589 (p: 0.000)
# bill_depth_mm-bill_length_mm: -0.229 (p: 0.000)
# bill_depth_mm-flipper_length_mm: -0.578 (p: 0.000)
# bill_depth_mm-body_mass_g: -0.472 (p: 0.000)
# flipper_length_mm-bill_length_mm: 0.653 (p: 0.000)
# flipper_length_mm-bill_depth_mm: -0.578 (p: 0.000)
# flipper_length_mm-body_mass_g: 0.873 (p: 0.000)
# body_mass_g-bill_length_mm: 0.589 (p: 0.000)
# body_mass_g-bill_depth_mm: -0.472 (p: 0.000)
# body_mass_g-flipper_length_mm: 0.873 (p: 0.000)

# %%
r, p = stats.pearsonr(df["body_mass_g"], df["bill_length_mm"])
r2 = r**2

print(f"r: {r:.3f}, r^2: {r2:.3f}, p: {p:.3f}")
# Out:
# r: 0.589, r^2: 0.347, p: 0.000
