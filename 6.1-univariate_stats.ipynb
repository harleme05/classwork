# %% [markdown]
# Notes:
#
# -Univariate Stats = Mesure of dist of ONE variable
# - 4 types[central tentency, dispersion, shape, graphical representation]

# %% [markdown]
# Central Tendency:
#
# - Mean = avrage
# - median = middle value when sorted
# - Mode = most frequent value

# %% [markdown]
# Dispursion:
# - Range(max, min)
# - Variance = how far away is the avrage datum from the denter
# - Sds = squere root of variance.

# %% [markdown]
# Variance
# - s^2 is sample variance
# - n is the number of observationd in thr dsmple
# - x_i is the ith obd in the sample
# - x.bar 0 sample mesm.
