# %%
import pandas as pd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/soccer-players.csv"

df = pd.read_csv(url)

# %%
from functions.convertion_cm_to_inches import convert_height

df["height_in_inches"] = df["height_in_cm"].apply(convert_height)
df["height_in_inches"]
# Out:
# 0        6.036749
# 1        6.233599
# 2             NaN
# 3             NaN
# 4        6.364833
#            ...
# 32398    5.839898
# 32399    5.905515
# 32400    5.380580
# 32401         NaN
# 32402         NaN
# Name: height_in_inches, Length: 32403, dtype: float64

# %%
df.loc[df["country_of_birth"]=="Norway"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32398    False
# 32399    False
# 32400    False
# 32401    False
# 32402    False
# Name: country_of_birth, Length: 32403, dtype: bool
